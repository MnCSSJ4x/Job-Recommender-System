# %%
from transformers import AutoTokenizer, AutoModel
import torch
import pandas as pd
import itertools
import torch.nn.functional as F
import numpy as np
import pickle

if torch.cuda.is_available():
    device='cuda'
else:
    device='cpu'
print(device)
# Out:
# cuda

# %% [markdown]
# ### Loading Transformers

# %%
tokenizer = AutoTokenizer.from_pretrained("MohammedDhiyaEddine/job-skill-sentence-transformer-tsdae")
model = AutoModel.from_pretrained("MohammedDhiyaEddine/job-skill-sentence-transformer-tsdae").to(device)
# tokenizer = AutoTokenizer.from_pretrained("/kaggle/input/jobbert-self-supervised/JOBBERT_FINETUNED_tokenizer")
# model = AutoModel.from_pretrained("/kaggle/input/jobbert-self-supervised/JOBBERT_FINETUNED").to(device)

# %%
# Open the pickle file for reading
with open('/kaggle/input/embeddings/jobEmbeddingArya.pickle', 'rb') as f:
#     Use pickle to load the variable from the file
    job_embeddings = pickle.load(f)

# Print the loaded variable
print(job_embeddings.shape)
# Out:
# torch.Size([828, 768])

# %%
user_df=pd.read_csv("/kaggle/input/userresume/UserResume.csv").dropna().drop(["Resume"],axis=1)
user_df.head()
user_df["Combined"] = user_df["Category"].astype(str) + user_df["Cleaned_Resume"]
user_df=user_df.drop(["Category","Cleaned_Resume"],axis=1)
user_df.head()
# Out:
#                                             Combined
# 0  Data ScienceSkills Programming Languages Pytho...
# 1  Data ScienceEducation Details May 2013 to May ...
# 2  Data ScienceAreas of Interest Deep Learning Co...
# 3  Data ScienceSkills R Python SAP HANA Tableau S...
# 4  Data ScienceEducation Details MCA YMCAUST Fari...

# %%
def mean_pooling(model_output, attention_mask):
        token_embeddings = model_output[0] #First element of model_output contains all token embeddings
        input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
        return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)
def getUserEmbedding(userResume):
    embeddings=torch.Tensor([]).to(device)#(np.zeros((n,df.shape[1],max_len,768)))
    sentences =userResume
    encoded_sentences = tokenizer(sentences, padding=True, truncation=True, return_tensors="pt")
    encoded_sentences.to(device)
    with torch.no_grad():
        temp=model(**encoded_sentences)
    sentence_embeddings = mean_pooling(temp, encoded_sentences['attention_mask'])
    embeddings=sentence_embeddings
    return embeddings
getUserEmbedding(user_df.iloc[0].Combined).shape
# Out:
# torch.Size([1, 768])

# %%
getUserEmbedding("I am familiar with python")

# %%
# df=pd.read_csv("/kaggle/input/scrapeddata/cleaned_jobs.csv")
df=pd.read_excel("/kaggle/input/jobs-xlsx/Jobs.xlsx").reset_index()
df=df.rename(columns={'index':'Index','Job Description':'Description'})
df=df.set_index('Index')
df.head()
# Out:
#                                                 Position             Company  \
# Index
# 0                          Kinaxis Application Developer  Accenture in India
# 1      ForgeRock Identity Management Security Deliver...  Accenture in India
# 2             Clinical - SDTM Programming Senior Analyst  Accenture in India
# 3             Ping Identity Solutions Security Architect  Accenture in India
# 4                                      PL/ SQL Developer       NR Consulting
#
#                           Location  \
# Index
# 0      Bengaluru, Karnataka, India
# 1      Bengaluru, Karnataka, India
# 2      Bengaluru, Karnataka, India
# 3      Bengaluru, Karnataka, India
# 4      Bengaluru, Karnataka, India
#
#                                              Description
# Index
# 0      About the job\nAbout Accenture: Accenture is a...
# 1                                          About the job
# 2      About the job\nSkill required: Clinical - SDTM...
# 3      About the job\nAbout Accenture: Accenture is a...
# 4      About the job\n Detailed JD-\n\nDevelop proced...

# %%
import re
from bs4 import BeautifulSoup
def cleanResume(resumeText):
    soup=BeautifulSoup(resumeText,"html.parser")
    resumeText=soup.get_text()
    resumeText = re.sub('http\S+\s*', ' ', resumeText)  # remove URLs
    resumeText = re.sub('RT|cc', ' ', resumeText)  # remove RT and cc
    resumeText = re.sub('#\S+', '', resumeText)  # remove hashtags
    resumeText = re.sub('@\S+', '  ', resumeText)  # remove mentions
    resumeText = re.sub('[%s]' % re.escape("""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""), ' ', resumeText)  # remove punctuations
    resumeText = re.sub(r'[^\x00-\x7f]',r' ', resumeText) 
    resumeText = re.sub('\s+', ' ', resumeText)  # remove extra whitespace
    return resumeText
    
df['Cleaned_Description'] = df.Description.apply(lambda x: cleanResume(x))
df
# Out:
# /opt/conda/lib/python3.7/site-packages/bs4/__init__.py:439: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   MarkupResemblesLocatorWarning
#                                                 Position  \
# Index
# 0                          Kinaxis Application Developer
# 1      ForgeRock Identity Management Security Deliver...
# 2             Clinical - SDTM Programming Senior Analyst
# 3             Ping Identity Solutions Security Architect
# 4                                      PL/ SQL Developer
# ...                                                  ...
# 969          Data Engineer - Azure Data Factory/DataLake
# 970                                     Python Developer
# 971                                        C++ Developer
# 972                                  Azure Data Engineer
# 973           DevOps Engineer - Linux/System Maintenance
#
#                            Company                           Location  \
# Index
# 0               Accenture in India        Bengaluru, Karnataka, India
# 1               Accenture in India        Bengaluru, Karnataka, India
# 2               Accenture in India        Bengaluru, Karnataka, India
# 3               Accenture in India        Bengaluru, Karnataka, India
# 4                    NR Consulting        Bengaluru, Karnataka, India
# ...                            ...                                ...
# 969                    Zelus India        Bengaluru, Karnataka, India
# 970        CloudPanel Technologies  Bengaluru North, Karnataka, India
# 971    Onnet Systems India Pvt Ltd        Bengaluru, Karnataka, India
# 972                       ZENFINET        Bengaluru, Karnataka, India
# 973                    Simplify360        Bengaluru, Karnataka, India
#
#                                              Description  \
# Index
# 0      About the job\nAbout Accenture: Accenture is a...
# 1                                          About the job
# 2      About the job\nSkill required: Clinical - SDTM...
# 3      About the job\nAbout Accenture: Accenture is a...
# 4      About the job\n Detailed JD-\n\nDevelop proced...
# ...                                                  ...
# 969    About the job\n\nDeveloper is responsible for ...
# 970    About the job\nThis job is sourced from a job ...
# 971    About the job\nJob Description\n\nThe ideal ca...
# 972    About the job\nPosition - Azure Data Engineer\...
# 973    About the job\n\nABOUT US :\n\nFormed with the...
#
#                                      Cleaned_Description
# Index
# 0      About the job About A enture A enture is a glo...
# 1                                          About the job
# 2      About the job Skill required Clinical SDTM Pro...
# 3      About the job About A enture A enture is a glo...
# 4      About the job Detailed JD Develop procedure an...
# ...                                                  ...
# 969    About the job Developer is responsible for cre...
# 970    About the job This job is sourced from a job b...
# 971    About the job Job Description The ideal candid...
# 972    About the job Position Azure Data Engineer Man...
# 973    About the job ABOUT US Formed with the vision ...
#
# [974 rows x 5 columns]

# %%
import math
def getCosineMatrix(userResume):
    user_embedding=getUserEmbedding(userResume)
#     print(user_embedding.shape)
#     print(job_embeddings.shape)
    # Create two example tensors
    tensor1 = user_embedding
    tensor2 = job_embeddings

    # Generate all permutations of the two tensors
    permutations = itertools.product(tensor1, tensor2)

    # Convert tuples to rows in a DataFrame
    Embedding_df = pd.DataFrame(permutations, columns=['tensor1', 'tensor2'])

    # Display the resulting DataFrame
#     print(Embedding_df.shape)
    Embedding_df['Index']=range(tensor2.shape[0])
    Embedding_df.set_index('Index')
    Embedding_df['cosine_similarity']=np.zeros((Embedding_df.shape[0]))
#     print(Embedding_df.shape)

    for i in range(math.ceil(Embedding_df.shape[0])):
        tensor1 = Embedding_df.iloc[i]['tensor1']
        tensor2 = Embedding_df.iloc[i]['tensor2']
    # compute the cosine similarity between the two tensors
        cosine_similarity_value = F.cosine_similarity(tensor1.unsqueeze(0), tensor2.unsqueeze(0)).item()
        Embedding_df['cosine_similarity'].iloc[i]=cosine_similarity_value
    Embedding_df = Embedding_df.sort_values(by='cosine_similarity', ascending=False)
    
    merged_df = pd.merge(Embedding_df, df, on='Index').set_index('Index')
#     merged_df
    
    return Embedding_df,merged_df

CosineMatrix,merged_df=getCosineMatrix("I am familiar with python")
CosineMatrix.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#                                                tensor1  \
# 323  [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
# 614  [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
# 769  [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
# 141  [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
# 639  [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
#
#                                                tensor2  Index  \
# 323  [tensor(-0.6617, device='cuda:0'), tensor(-0.0...    323
# 614  [tensor(-0.8616, device='cuda:0'), tensor(0.30...    614
# 769  [tensor(-0.7978, device='cuda:0'), tensor(0.32...    769
# 141  [tensor(-0.7639, device='cuda:0'), tensor(0.15...    141
# 639  [tensor(-0.4676, device='cuda:0'), tensor(0.28...    639
#
#      cosine_similarity
# 323           0.782478
# 614           0.778540
# 769           0.776148
# 141           0.772601
# 639           0.759796

# %%
merged_df.head()
# Out:
#                                                  tensor1  \
# Index
# 323    [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
# 614    [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
# 769    [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
# 141    [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
# 639    [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
#
#                                                  tensor2  cosine_similarity  \
# Index
# 323    [tensor(-0.6617, device='cuda:0'), tensor(-0.0...           0.782478
# 614    [tensor(-0.8616, device='cuda:0'), tensor(0.30...           0.778540
# 769    [tensor(-0.7978, device='cuda:0'), tensor(0.32...           0.776148
# 141    [tensor(-0.7639, device='cuda:0'), tensor(0.15...           0.772601
# 639    [tensor(-0.4676, device='cuda:0'), tensor(0.28...           0.759796
#
#                                                 Position        Company  \
# Index
# 323                  Python Developer | Bangalore, India    Eastvantage
# 614                                         Data Analyst          Glean
# 769    Java Developer - Java, Microservice, Kafka, Sp...  XCUTIVES Inc.
# 141                             Data Engineer(ADF.T-SQL)   Diverse Lynx
# 639                                       java developer   Diverse Lynx
#
#                           Location  \
# Index
# 323    Bengaluru, Karnataka, India
# 614    Bengaluru, Karnataka, India
# 769    Bengaluru, Karnataka, India
# 141    Bengaluru, Karnataka, India
# 639    Bengaluru, Karnataka, India
#
#                                              Description  \
# Index
# 323    About the job\nLocation:\n\nBangalore, India\n...
# 614    About the job\nAbout Glean\n\nWe're on a missi...
# 769    About the job\nPosition : Senior Software Engi...
# 141    About the job\nCreate and maintain optimal dat...
# 639    About the job\nLooking for Java developer\n\n3...
#
#                                      Cleaned_Description
# Index
# 323    About the job Location Bangalore India Contrac...
# 614    About the job About Glean We re on a mission t...
# 769    About the job Position Senior Software Enginee...
# 141    About the job Create and maintain optimal data...
# 639    About the job Looking for Java developer 3 Yea...

# %%
merged_df.drop(["Company","Location"],axis=1,inplace=True)
merged_df
# Out:
#                                                  tensor1  \
# Index
# 323    [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
# 614    [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
# 769    [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
# 141    [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
# 639    [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
# ...                                                  ...
# 453    [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
# 215    [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
# 758    [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
# 564    [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
# 522    [tensor(-0.1596, device='cuda:0'), tensor(-0.1...
#
#                                                  tensor2  cosine_similarity  \
# Index
# 323    [tensor(-0.6617, device='cuda:0'), tensor(-0.0...           0.782478
# 614    [tensor(-0.8616, device='cuda:0'), tensor(0.30...           0.778540
# 769    [tensor(-0.7978, device='cuda:0'), tensor(0.32...           0.776148
# 141    [tensor(-0.7639, device='cuda:0'), tensor(0.15...           0.772601
# 639    [tensor(-0.4676, device='cuda:0'), tensor(0.28...           0.759796
# ...                                                  ...                ...
# 453    [tensor(0.1776, device='cuda:0'), tensor(0.378...           0.310196
# 215    [tensor(-0.3414, device='cuda:0'), tensor(0.44...           0.307775
# 758    [tensor(0.1364, device='cuda:0'), tensor(-0.15...           0.301227
# 564    [tensor(0.0924, device='cuda:0'), tensor(0.601...           0.300035
# 522    [tensor(-0.1310, device='cuda:0'), tensor(0.78...           0.275574
#
#                                                 Position  \
# Index
# 323                  Python Developer | Bangalore, India
# 614                                         Data Analyst
# 769    Java Developer - Java, Microservice, Kafka, Sp...
# 141                             Data Engineer(ADF.T-SQL)
# 639                                       java developer
# ...                                                  ...
# 453                  DB developer (Data Base Developers)
# 215    Interesting Job Opportunity: Automation Test E...
# 758                           Devops Implementation Engg
# 564                    Software Development Engineer III
# 522    IoTian Technologies - Machine Learning Enginee...
#
#                                              Description  \
# Index
# 323    About the job\nLocation:\n\nBangalore, India\n...
# 614    About the job\nAbout Glean\n\nWe're on a missi...
# 769    About the job\nPosition : Senior Software Engi...
# 141    About the job\nCreate and maintain optimal dat...
# 639    About the job\nLooking for Java developer\n\n3...
# ...                                                  ...
# 453                                        About the job
# 215    About the job\nThis job is sourced from a job ...
# 758    About the job\nKey Responsibilities: Infrastru...
# 564    About the job\nJob Title\n\nSenior software De...
# 522    About the job\nOnly candidates from IIT /NIT m...
#
#                                      Cleaned_Description
# Index
# 323    About the job Location Bangalore India Contrac...
# 614    About the job About Glean We re on a mission t...
# 769    About the job Position Senior Software Enginee...
# 141    About the job Create and maintain optimal data...
# 639    About the job Looking for Java developer 3 Yea...
# ...                                                  ...
# 453                                        About the job
# 215    About the job This job is sourced from a job b...
# 758    About the job Key Responsibilities Infrastruct...
# 564    About the job Job Title Senior software Develo...
# 522    About the job Only candidates from IIT NIT may...
#
# [828 rows x 6 columns]

# %%
grouped_df = merged_df.groupby('Position').mean().sort_values(by='cosine_similarity', ascending=False)
grouped_df
# Out:
#                                                     cosine_similarity
# Position
# Java Developer - Java, Microservice, Kafka, Spr...           0.776148
# Data Engineer(ADF.T-SQL)                                     0.772601
# Software Dev Principal Engineer - Python and Ne...           0.753128
# Data Analytics Engineer - Python/SQL                         0.749961
# Java Engineer - New - 52 <Test Job Visible to L...           0.742830
# ...                                                               ...
# Data Analytics Senior Analyst                                0.310880
# Interesting Job Opportunity: Automation Test En...           0.307775
# Devops Implementation Engg                                   0.301227
# Software Development Engineer III                            0.300035
# IoTian Technologies - Machine Learning Engineer...           0.275574
#
# [597 rows x 1 columns]
